# %% [markdown]
# # Nyan Cafe Simulation
# Esta es una simulación de una cafetería que consta de ```<nTables>``` mesas, cada una con una capacidad para ```<TABLE_CAPACITY>``` personas.
# Cada ```<SPAWN_TIME>``` minutos se generá un grupo de personas de tamaño ```<GROUP_SIZE>``` que vienen juntas a ocupar una mesa.
#
# Cuando un grupo de personas llega a la cafetería, solicitan una mesa (aleatoriamente); si la mesa no esta disponible, quedan en cola, esperando a que se desocupe esa mesa; en caso de que la mesa sí este disponible, el grupo pasa a ocuparla y empezará a revisarla, si ```<GROUP_SIZE>``` es mayor a ```<TABLE_CAPACITY>``` el grupo se irá de la mesa inmediatamente.
#
# Cuando el grupo de personas toma una mesa, hacen un pedido de ```<GROUP_SIZE>``` cafés a un gato robot (seleccionado aleatoriamente), el cúal los atenderá si esta desocupado; si no esta desocupado, los pondrá en cola; en caso de no tener más suministros en su tanque, despachará a las personas de la mesa.
#
# Cuando el grupo de personas es atendido por el gato robot, este tardará ```<GROUP_SIZE> X <COFFEE_TIME>``` minutos en preparar sus cafés, luego el gato robot los servirá y pasará a estar desocupado, pero la mesa seguirá ocupada por el grupo de personas por ```between <MIN_DRINKING_TIME> and <MAX_DRINKING_TIME>``` minutos más antes de ser desocupada.
#
# Por cada taza de café, los gatos robots gastan ```<gramsPerCoffee>``` gramos de café de su tanque de ```<TANK_CAPACITY>``` gramos de capacidad.
# La cafetería tendrá una cantidad de ```<nCatRobot>``` gatos robots funcionando en ella.

# %% [markdown]
# ## Descripción de variables, eventos y enfoque
# En este caso se hará enfoque en la cantidad de mesas, la cantidad de gatos robot, el tiempo promedio que esperan en cola los clientes y las tazas de café que servimos.
#
#
# Teniendo en cuenta lo anterior, asignaremos ya algunas variables por defecto:

# %%
# Importamos las librerias necesarias
import simpy
import pandas as pd
import random

# Definimos algunas variables por defecto
RANDOM_SEED = 42
TABLE_CAPACITY = 4 # Capacidad de las mesas (Fija a 4 personas)
SPAWN_TIME = 25 # Tiempo máximo de llegada de los grupos clientes (1 a 25 minutos)
GROUP_SIZE = 4 # Tamaño máximo de los grupos de clientes (1 a 4 personas)

MIN_DRINKING_TIME = 10 # Tiempo mínimo de consumo de una taza de café (10 minutos)
MAX_DRINKING_TIME = 30 # Tiempo máximo de consumo de una taza de café (30 minutos)

COFFEE_TIME = 5 # Tiempo máximo de preparación de una taza de café (1 a 5 minutos)
GRAMS_PER_COFFEE = 5 # Gasto de café por taza (Fijo a 5 gramos)
TANK_CAPACITY = 1000 # Capacidad en gramos del tanque de café de los gatos robots (Fijo a 1000 gramos)

# Definimos los eventos que pueden ocurrir
class Event:
    TOO_MANY_PEOPLE = "TOO_MANY_PEOPLE" # Grupo de clientes muy grande para la mesa
    WAITING_IN_LINE = "WAITING_IN_LINE" # Grupo de clientes esperando en la cola por su mesa
    TABLE_TAKEN = "TABLE_TAKEN", # Grupo de clientes tomando la mesa
    NOT_ENOUGH_COFFEE = "NOT_ENOUGH_COFFEE" # Falta de café en el tanque de los gatos robots para preparar el pedido
    MAKING_COFFEE = "MAKING_COFFEE" # Los gatos robots están preparando el pedido
    DRINKING_COFFEE = "DRINKING_COFFEE" # Grupo de clientes recibe y empieza a consumir su café
    DRINKING_COFFEE_FINISHED = "DRINKING_COFFEE_FINISHED" # Grupo de clientes terminó de consumir su café
    COFFEE_REQ_FINISHED = "COFFEE_REQ_FINISHED" # La visita y los pedidos de café han terminado y el grupo de clientes se va (incluye a los que no pudieron ser atendidos)

event = Event()

# %% [markdown]
# ## Definición de las clases

# %%
class Table: # Mesas de la cafetería
    def __init__(self, env, name, capacity):
        self.env = env
        self.name = name
        self.capacity = capacity # Capacidad de la mesa (En personas) *NO CONFUNDIR CON LA CAPACIDAD DEl RESOURCE*
        self.resource = simpy.Resource(env, capacity=1)

        self.dfT = pd.DataFrame({
            "name": [name],
            "capacity": [capacity]
        })

        self.dfE = pd.DataFrame()

    def receiveGroup(self, group):
        print(f"[{self.env.now }] {group.name}: Esta revisando {self.name}")
        yield self.env.timeout(1) # Tiempo de revisión de la mesa
        if self.capacity < group.size:
            print(f"[{self.env.now}] {group.name}: No encontró suficiente espacio en {self.name} (gSize:{group.size}) (tSize:{self.capacity})")
            df = pd.DataFrame({
                "time": [self.env.now],
                "robocat": [group.robocat.name],
                "table": [self.name],
                "group": [group.name],
                "group_size": [group.size],
                "event": [event.TOO_MANY_PEOPLE]
            })
            self.dfE = pd.concat( [ self.dfE , df ] )

        else:
            print(f"[{self.env.now}] {group.name}: Encontró suficiente espacio en {self.name} (gSize:{group.size}) (tSize:{self.capacity})")
            df = pd.DataFrame({
                "time": [self.env.now],
                "robocat": [group.robocat.name],
                "table": [self.name],
                "group": [group.name],
                "group_size": [group.size],
                "event": [event.TABLE_TAKEN]
            })
            self.dfE = pd.concat( [ self.dfE , df ] )
            group.hasTable = True

# %%
class Group: # Grupo de clientes que llegan a la cafetería
    def __init__(self, env, name, size, drinkingTime, table, robocats):
        self.env = env
        self.name = name
        self.size = size
        self.drinkingTime = drinkingTime
        self.table = table
        self.hasTable = False
        self.wasAttended = False
        self.robocat = random.choice(robocats)

        self.dfG = pd.DataFrame({
            "name": [name],
            "size": [size],
            "drinkingTime": [drinkingTime],
            "table": [table.name]
        })

        self.dfE = pd.DataFrame()

        env.process(self.in_line())

    def in_line(self): 
        print(f"[{self.env.now}] {self.name}: Esta esperando la {self.table.name}")
        df = pd.DataFrame({
            "time": [self.env.now],
            "robocat": [self.robocat.name],
            "table": [self.table.name],
            "group": [self.name],
            "group_size": [self.size],
            "event": [event.WAITING_IN_LINE]
        })
        self.dfE = pd.concat([self.dfE, df])

        with self.table.resource.request() as table_request:
            yield table_request
            print(f"[{self.env.now}] {self.name}: Ha tomado la {self.table.name}")
            yield self.env.process(self.table.receiveGroup(self))
            if self.hasTable:
                df = pd.DataFrame({
                    "time": [self.env.now],
                    "robocat": [self.robocat.name],
                    "table": [self.table.name],
                    "group": [self.name],
                    "group_size": [self.size],
                    "event": [event.TABLE_TAKEN]
                })
                self.dfE = pd.concat([self.dfE, df])
                print(f"[{self.env.now}] {self.name}: Esperando para pedir a {self.robocat.name}")
                
                with self.robocat.resource.request() as robocat_request:
                    yield robocat_request
                    print(f"[{self.env.now}] {self.robocat.name}: Escuchando a {self.name} ")
                    yield self.env.process(self.robocat.makeCoffee(self, self.table))
                if self.wasAttended:
                    print(f"[{self.env.now}] {self.name}: Recibió su café de {self.robocat.name} y se estará {self.drinkingTime} minutos en la mesa")
                    df = pd.DataFrame({
                        "time": [self.env.now],
                        "robocat": [self.robocat.name],
                        "table": [self.table.name],
                        "group": [self.name],
                        "group_size": [self.size],
                        "event": [event.DRINKING_COFFEE]
                    })
                    self.dfE = pd.concat([self.dfE, df])
                    yield self.env.timeout(self.drinkingTime) # Tiempo de espera de clientes consumiendo café en la mesa
                    df = pd.DataFrame({
                        "time": [self.env.now],
                        "robocat": [self.robocat.name],
                        "table": [self.table.name],
                        "group": [self.name],
                        "group_size": [self.size],
                        "event": [event.DRINKING_COFFEE]
                    })
                    self.dfE = pd.concat([self.dfE, df])
                df = pd.DataFrame({
                    "time": [self.env.now],
                    "robocat": [self.robocat.name],
                    "table": [self.table.name],
                    "group": [self.name],
                    "group_size": [self.size],
                    "event": [event.COFFEE_REQ_FINISHED]
                })
                self.dfE = pd.concat([self.dfE, df])
            print(f"[{self.env.now}] {self.name}: Abandonó la mesa {self.table.name}")

# %%
class RoboCat: # Gatos robots que preparan el café
    def __init__(self, env, name, tankCapacity, coffeeTime):
        self.env = env
        self.name = name
        self.tankCapacity = tankCapacity
        self.coffeeTime = coffeeTime
        self.tank = simpy.Container(env, init=tankCapacity, capacity=tankCapacity)
        self.resource = simpy.Resource(env, capacity=1)

        self.dfR = pd.DataFrame({
            "name": [name],
            "tankCapacity": [tankCapacity],
            "coffeeTime": [coffeeTime]
        })

        self.dfE = pd.DataFrame() # Dataframe para recolectar todos los eventos

    def makeCoffee(self, group, table):

        totalCoffeeGrams = group.size * GRAMS_PER_COFFEE
        print(f"[{self.env.now}] {self.name}: Procesando pedido de {group.name} en {group.table.name} (pedido:{totalCoffeeGrams}g) (tank:{self.tank.level}/{self.tankCapacity}g)")

        if self.tank.level < totalCoffeeGrams:
            print(f"[{self.env.now}] {self.name}: No hay suficiente café para {group.name}, {group.table.name}, (pedido:{totalCoffeeGrams}g) (tank:{self.tank.level}/{self.tankCapacity}g)")
            df = pd.DataFrame({
                "time": [self.env.now],
                "robocat": [self.name],
                "table": [table.name],
                "group": [group.name],
                "group_size": [group.size],
                "event": [event.NOT_ENOUGH_COFFEE]
            })
            self.dfE = pd.concat( [ self.dfE , df ] )
        else:
            yield self.tank.get(totalCoffeeGrams)
            totalCoffeeTime = group.size * self.coffeeTime
            print( f"[{self.env.now}] {self.name}: Preparando {group.size} cafés en {totalCoffeeTime} minutos (newtank:{self.tank.level}/{self.tankCapacity}g)" )
            df = pd.DataFrame({
                "time": [self.env.now],
                "robocat": [self.name],
                "table": [table.name],
                "group": [group.name],
                "group_size": [group.size],
                "event": [event.MAKING_COFFEE]
            })
            self.dfE = pd.concat( [ self.dfE , df ] )

            yield self.env.timeout(totalCoffeeTime)
            group.wasAttended = True

# %%
class NyanCafe: # Cafetería
    def __init__(self, env, tableCapacity, spawnTime, groupSize, pMinDrinkingTime, pDrinkingTime, coffeeTime, gramsPerCoffee, tankCapacity, nRobocats, nTables, nGroups):
        self.env = env
        self.tableCapacity = tableCapacity
        self.spawnTime = spawnTime
        self.groupSize = groupSize
        self.pMinDrinkingTime = pMinDrinkingTime
        self.pDrinkingTime = pDrinkingTime
        self.coffeeTime = coffeeTime
        self.gramsPerCoffee = gramsPerCoffee
        self.tankCapacity = tankCapacity
        self.nGroups = nGroups
        self.groups = []

        self.tables = [
            Table(
                env, 
                f"Table{i}", 
                tableCapacity
            ) for i in range(nTables)
        ]
        self.robocats = [
            RoboCat(
                env, 
                f"RoboCat{i}", 
                tankCapacity, 
                coffeeTime
            ) for i in range(nRobocats)
        ]

        env.process(self.spawnGroups())

    def spawnGroups(self):
        for i in range( self.nGroups ):
            size = random.randint(1, self.groupSize)
            drinkingTime = random.randint(self.pMinDrinkingTime, self.pDrinkingTime)
            table = random.choice(self.tables)
            self.groups.append(
                Group(
                    self.env, 
                    f"Group{i}", 
                    size, 
                    drinkingTime, 
                    table, 
                    self.robocats
                )
            )
            yield self.env.timeout(random.randint(1, self.spawnTime))

# %% [markdown]
# ## Simulación

# %%
# Añadimos una semilla para que los resultados sean reproducibles
random.seed(RANDOM_SEED)
SIMULATIOM_TIME = 16*60 # horas

# Definimos el ambiente que vamos a simular
env =  simpy.Environment()
nyanCafe = NyanCafe(
    env, 
    TABLE_CAPACITY, 
    SPAWN_TIME, 
    GROUP_SIZE, 
    MIN_DRINKING_TIME, 
    MAX_DRINKING_TIME, 
    COFFEE_TIME, 
    GRAMS_PER_COFFEE, 
    TANK_CAPACITY, 
    nRobocats=2, # Número de gatos robots que preparan café
    nTables=3, # Número de mesas en la cafetería
    nGroups=100 # Número máximo de grupos de clientes que podrían spawnear en la cafetería
)
env.run( until=SIMULATIOM_TIME )
# Out:
# [0] Group0: Esta esperando la Table2
# [0] Group0: Ha tomado la Table2
# [0] Group0: Esta revisando Table2
# [1] Group0: Encontró suficiente espacio en Table2 (gSize:1) (tSize:4)
# [1] Group0: Esperando para pedir a RoboCat1
# [1] RoboCat1: Escuchando a Group0
# [1] RoboCat1: Procesando pedido de Group0 en Table2 (pedido:5g) (tank:1000/1000g)
# [1] RoboCat1: Preparando 1 cafés en 5 minutos (newtank:995/1000g)
# [6] Group0: Recibió su café de RoboCat1 y se estará 10 minutos en la mesa
# [8] Group1: Esta esperando la Table2
# [16] Group0: Abandonó la mesa Table2
# [16] Group1: Ha tomado la Table2
# [16] Group1: Esta revisando Table2
# [17] Group1: Encontró suficiente espacio en Table2 (gSize:2) (tSize:4)
# [17] Group1: Esperando para pedir a RoboCat0
# [17] RoboCat0: Escuchando a Group1
# [17] RoboCat0: Procesando pedido de Group1 en Table2 (pedido:10g) (tank:1000/1000g)
# [17] RoboCat0: Preparando 2 cafés en 10 minutos (newtank:990/1000g)
# ...

# %% [markdown]
# ## Recolectar los Dataframes

# %%
df_events = pd.DataFrame()

# %%
df_robocats = pd.DataFrame()

for r in nyanCafe.robocats:
    df_robocats = pd.concat([ df_robocats , r.dfR ])
    df_events = pd.concat([ df_events , r.dfE ])

# %%
df_groups = pd.DataFrame()

for g in nyanCafe.groups:
    df_groups = pd.concat([ df_groups , g.dfG ])
    df_events = pd.concat([ df_events , g.dfE ])

# %%
df_tables = pd.DataFrame()

for t in nyanCafe.tables:
    df_tables = pd.concat([ df_tables , t.dfT ])
    df_events = pd.concat([ df_events , t.dfE ])

# %%
df_groups.head(5)
# Out:
#      name  size  drinkingTime   table
# 0  Group0     1            10  Table2
# 0  Group1     2            14  Table2
# 0  Group2     1            28  Table1
# 0  Group3     1            16  Table0
# 0  Group4     2            30  Table2

# %%
df_robocats
# Out:
#        name  tankCapacity  coffeeTime
# 0  RoboCat0          1000           5
# 0  RoboCat1          1000           5

# %%
df_tables
# Out:
#      name  capacity
# 0  Table0         4
# 0  Table1         4
# 0  Table2         4

# %% [markdown]
# ## Análisis de los dataframes de la simulación

# %% [markdown]
# ### Cuál fue el primer y cuál fue el ultimó momento en que **inició a producir** café cada Robocat

# %%
df_events.loc[ 
    ( df_events["event"].isin([event.MAKING_COFFEE]) )
, :  ].groupby(
    "robocat"
).agg({
    "time": ["min", "max"]
})
# Out:
#          time
#           min  max
# robocat
# RoboCat0   17  950
# RoboCat1    1  952

# %% [markdown]
# ### Total clientes atendidos y cuál es es tamaño promedio de los grupos en que llegan

# %%
total_customer_groups_served = df_events.loc[ df_events['event'] == event.DRINKING_COFFEE , : ].shape[0]

total_cups_served = df_events.loc[ df_events['event'] == event.DRINKING_COFFEE , 'group_size' ].sum()

average_customer_groups_size = df_events.loc[ df_events['event'] == event.WAITING_IN_LINE , 'group_size' ].mean()

print(f"Promedio de tamaño de grupos de clientes: {average_customer_groups_size}")
print(f"Total de grupos de clientes spawneados: {df_groups.shape[0]}")
print(f"Total de grupos de clientes servidos: {total_customer_groups_served}")
print(f"Total tazas de café servidas: {total_cups_served}")
# Out:
# Promedio de tamaño de grupos de clientes: 2.4615384615384617
# Total de grupos de clientes spawneados: 78
# Total de grupos de clientes servidos: 130
# Total tazas de café servidas: 318

# %% [markdown]
# ### Porcentage de clientes atendidos

# %%
df_events.loc[ df_events['event'] == event.DRINKING_COFFEE , : ].shape[0] / df_groups.shape[0]
# Out:
# 1.6666666666666667

# %% [markdown]
# ### Promedio de tiempo desde que el grupo de clientes hace cola hasta que se va de la mesa

# %%
attended = df_events.loc[ 
    df_events["event"].isin([ event.WAITING_IN_LINE , event.COFFEE_REQ_FINISHED ])
    , : 
].sort_values(["time"])

attended["prev_time"] = attended.groupby( "group" )["time"].shift(1)

attended = attended.loc[ ~attended["prev_time"].isnull() , : ]

attended["Espera"] = attended["time"] - attended["prev_time"]

mean_total_wait_time = attended["Espera"].mean()
mean_total_wait_time
# Out:
# 89.40625

# %% [markdown]
# ### Promedio de tiempo desde que el grupo de clientes hace cola hasta que toma una mesa

# %%
attended = df_events.loc[ 
    df_events["event"].isin([ event.WAITING_IN_LINE , event.TABLE_TAKEN ])
    , : 
].sort_values(["time"])

attended["prev_time"] = attended.groupby( "group" )["time"].shift(1)

attended = attended.loc[ ~attended["prev_time"].isnull() , : ]

attended["Espera"] = attended["time"] - attended["prev_time"]

mean_table_wait_time = attended["Espera"].mean()
mean_table_wait_time
# Out:
# 28.16417910447761

# %% [markdown]
# ### Promedio de tiempo que el grupo usa la mesa hasta que se va

# %%
mean_total_wait_time - mean_table_wait_time
# Out:
# 61.24207089552239

# %% [markdown]
# ### Tazas que produjo cada robocat

# %%
cups_per_robocat = df_events.loc[
    df_events["event"] == event.MAKING_COFFEE, :
].groupby('robocat', as_index=False).agg({
    'group_size': ["min", "max", "sum"]
}).rename(columns={
    ('group_size', 'min'): 'min_tazas',
    ('group_size', 'max'): 'max_tazas',
    ('group_size', 'sum'): 'total_tazas'
})

cups_per_robocat.columns = ['robocat', 'min_tazas', 'max_tazas', 'total_tazas']
cups_per_robocat
# Out:
#     robocat  min_tazas  max_tazas  total_tazas
# 0  RoboCat0          1          4           93
# 1  RoboCat1          1          4           69
